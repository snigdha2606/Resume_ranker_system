# %% [markdown]
# <a href="https://colab.research.google.com/github/snigdha2606/Resume_ranker_system/blob/main/Automatic_resume_ranker_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from transformers import DistilBertTokenizer, DistilBertModel
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm


data = pd.read_csv("/content/UpdatedResumeDataSet.csv")

# Getting job that are tech area
list_tech = ['Java Developer', 'Testing', 'DevOps Engineer', 'Python Developer',
             'Web Designing', 'ETL Developer', 'Data Science', 'SAP Developer',
             'Network Security Engineer', 'Automation Testing', 'DotNet Developer',
             'Hadoop', 'Database', 'Blockchain']

data['Category Area'] = data['Category'].apply(lambda category: 'Tech' if category in list_tech else 'Non-tech')


data = data.reindex(columns=['Category', 'Category Area', 'Resume'])

# Define a custom PyTorch dataset
class ResumeDataset(Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}

    def __len__(self):
        return len(self.encodings.input_ids)


class SimilarityModel(nn.Module):
    def __init__(self):
        super(SimilarityModel, self).__init__()
        self.distilbert = DistilBertModel.from_pretrained('distilbert-base-uncased')

    def forward(self, input_ids, attention_mask):
        outputs = self.distilbert(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.last_hidden_state.mean(dim=1)
        return pooled_output


tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
model = SimilarityModel()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)


unique_categories = data['Category'].unique()


top_10_resumes_per_category = {}


def rank_resumes_for_category(category, data):
    category_data = data[data['Category'] == category]
    # Split data into training and testing sets
    train_data, _ = train_test_split(category_data, test_size=0.2, random_state=42)

    encoded_resumes = tokenizer.batch_encode_plus(train_data["Resume"].tolist(),
                                                  max_length=512,
                                                  truncation=True,
                                                  padding='max_length',
                                                  return_tensors='pt')

    resume_dataset = ResumeDataset(encoded_resumes)

    resume_loader = DataLoader(resume_dataset, batch_size=8, shuffle=False)
    # Extract embeddings for resumes
    resume_embeddings = []
    for batch in tqdm(resume_loader, desc=f'Embeddings for {category}', leave=False):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        with torch.no_grad():
            outputs = model(input_ids, attention_mask)
        resume_embeddings.append(outputs.cpu().numpy())
    resume_embeddings = np.concatenate(resume_embeddings)
    # Calculate average embeddings for resumes
    category_embedding = np.mean(resume_embeddings, axis=0)
    # Rank resumes based on cosine similarity with category embedding
    similarity_scores = cosine_similarity(resume_embeddings, [category_embedding])
    ranked_indices = np.argsort(similarity_scores.flatten())[::-1]
    ranked_resumes = train_data.iloc[ranked_indices[:10]]  # Select top 10 resumes
    return ranked_resumes

# Rank top 10 resumes for each category
for category in unique_categories:
    top_10_resumes_per_category[category] = rank_resumes_for_category(category, data)


for category, top_10_resumes in top_10_resumes_per_category.items():
    print("Top 10 resumes for category:", category)
    print(top_10_resumes)
    print("\n")
# Out:
# Embeddings for Data Science:   0%|          | 0/4 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for HR:   0%|          | 0/5 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Advocate:   0%|          | 0/2 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Arts:   0%|          | 0/4 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Web Designing:   0%|          | 0/5 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Mechanical Engineer:   0%|          | 0/4 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Sales:   0%|          | 0/4 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Health and fitness:   0%|          | 0/3 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Civil Engineer:   0%|          | 0/3 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Java Developer:   0%|          | 0/9 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Business Analyst:   0%|          | 0/3 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for SAP Developer:   0%|          | 0/3 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Automation Testing:   0%|          | 0/3 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Electrical Engineering:   0%|          | 0/3 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Operations Manager:   0%|          | 0/4 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Python Developer:   0%|          | 0/5 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for DevOps Engineer:   0%|          | 0/6 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Network Security Engineer:   0%|          | 0/3 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for PMO:   0%|          | 0/3 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Database:   0%|          | 0/4 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Hadoop:   0%|          | 0/5 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for ETL Developer:   0%|          | 0/4 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for DotNet Developer:   0%|          | 0/3 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Blockchain:   0%|          | 0/4 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Embeddings for Testing:   0%|          | 0/7 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Top 10 resumes for category: Data Science
#         Category Category Area  \
# 38  Data Science          Tech
# 8   Data Science          Tech
# 18  Data Science          Tech
# 28  Data Science          Tech
# 2   Data Science          Tech
# 22  Data Science          Tech
# 32  Data Science          Tech
# 31  Data Science          Tech
# 11  Data Science          Tech
# 1   Data Science          Tech
#
#                                                Resume
# 38  Personal Skills â¢ Ability to quickly grasp t...
# 8   Personal Skills â¢ Ability to quickly grasp t...
# 18  Personal Skills â¢ Ability to quickly grasp t...
# 28  Personal Skills â¢ Ability to quickly grasp t...
# 2   Areas of Interest Deep Learning, Control Syste...
# 22  Areas of Interest Deep Learning, Control Syste...
# 32  Areas of Interest Deep Learning, Control Syste...
# 31  Education Details \r\nMay 2013 to May 2017 B.E...
# 11  Education Details \r\nMay 2013 to May 2017 B.E...
# 1   Education Details \r\nMay 2013 to May 2017 B.E...
#
#
# Top 10 resumes for category: HR
#    Category Category Area                                             Resume
# 51       HR      Non-tech  TECHNICAL SKILLS â¢ Typewriting â¢ TORA â¢ ...
# 62       HR      Non-tech  TECHNICAL SKILLS â¢ Typewriting â¢ TORA â¢ ...
# 40       HR      Non-tech  TECHNICAL SKILLS â¢ Typewriting â¢ TORA â¢ ...
# 73       HR      Non-tech  TECHNICAL SKILLS â¢ Typewriting â¢ TORA â¢ ...
# 67       HR      Non-tech  Education Details \r\n BBA   lovely profession...
# 56       HR      Non-tech  Education Details \r\n BBA   lovely profession...
# 78       HR      Non-tech  Education Details \r\n BBA   lovely profession...
# 45       HR      Non-tech  Education Details \r\n BBA   lovely profession...
# 43       HR      Non-tech  Education Details \r\nJune 2012 to May 2015 B....
# 54       HR      Non-tech  Education Details \r\nJune 2012 to May 2015 B....
#
#
# Top 10 resumes for category: Advocate
#      Category Category Area                                             Resume
# 102  Advocate      Non-tech  Good grasping quality and skillful work Educat...
# 92   Advocate      Non-tech  Good grasping quality and skillful work Educat...
# 97   Advocate      Non-tech  Education Details \r\nNovember 2016 to January...
# 87   Advocate      Non-tech  Education Details \r\nNovember 2016 to January...
# 91   Advocate      Non-tech  Skills Legal Writing Efficient researcher Lega...
# 90   Advocate      Non-tech  Skills: Natural Languages: Proficient in Engli...
# 100  Advocate      Non-tech  Skills: Natural Languages: Proficient in Engli...
# 95   Advocate      Non-tech  Education Details \r\n B.Com, LL.B.,   Univers...
# 96   Advocate      Non-tech  Education Details \r\n LLB.   Dibrugarh Univer...
# 86   Advocate      Non-tech  Education Details \r\n LLB.   Dibrugarh Univer...
#
#
# Top 10 resumes for category: Arts
#     Category Category Area                                             Resume
# 121     Arts      Non-tech  I Other Skills Course/Skill Name Board Year Of...
# 133     Arts      Non-tech  I Other Skills Course/Skill Name Board Year Of...
# 127     Arts      Non-tech  I Other Skills Course/Skill Name Board Year Of...
# 109     Arts      Non-tech  I Other Skills Course/Skill Name Board Year Of...
# 115     Arts      Non-tech  I Other Skills Course/Skill Name Board Year Of...
# 111     Arts      Non-tech  â¢ Operating Systems: Windows XP / Vista / 07...
# 129     Arts      Non-tech  â¢ Operating Systems: Windows XP / Vista / 07...
# 123     Arts      Non-tech  â¢ Operating Systems: Windows XP / Vista / 07...
# 105     Arts      Non-tech  â¢ Operating Systems: Windows XP / Vista / 07...
# 104     Arts      Non-tech  â¢ Good communication skill â¢ Quick learner...
#
#
# Top 10 resumes for category: Web Designing
#           Category Category Area  \
# 147  Web Designing          Tech
# 145  Web Designing          Tech
# 142  Web Designing          Tech
# 155  Web Designing          Tech
# 177  Web Designing          Tech
# 167  Web Designing          Tech
# 140  Web Designing          Tech
# 170  Web Designing          Tech
# 172  Web Designing          Tech
# 157  Web Designing          Tech
#
#                                                 Resume
# 147  Technical Skills Web Technologies: Angular JS,...
# 145  Technical Skills Web Technologies: Angular JS,...
# 142  Technical Skills Web Technologies: Angular JS,...
# 155  Technical Skills Web Technologies: Angular JS,...
# 177  Technical Skills Web Technologies: Angular JS,...
# 167  Technical Skills Web Technologies: Angular JS,...
# 140  Technical Skills Web Technologies: Angular JS,...
# 170  Technical Skills Web Technologies: Angular JS,...
# 172  Technical Skills Web Technologies: Angular JS,...
# 157  Technical Skills Web Technologies: Angular JS,...
#
#
# Top 10 resumes for category: Mechanical Engineer
#                 Category Category Area  \
# 223  Mechanical Engineer      Non-tech
# 203  Mechanical Engineer      Non-tech
# 218  Mechanical Engineer      Non-tech
# 188  Mechanical Engineer      Non-tech
# 208  Mechanical Engineer      Non-tech
# 193  Mechanical Engineer      Non-tech
# 198  Mechanical Engineer      Non-tech
# 213  Mechanical Engineer      Non-tech
# 216  Mechanical Engineer      Non-tech
# 186  Mechanical Engineer      Non-tech
#
#                                                 Resume
# 223  Education Details \r\nJune 2014 to June 2018 B...
# 203  Education Details \r\nJune 2014 to June 2018 B...
# 218  Education Details \r\nJune 2014 to June 2018 B...
# 188  Education Details \r\nJune 2014 to June 2018 B...
# 208  Education Details \r\nJune 2014 to June 2018 B...
# 193  Education Details \r\nJune 2014 to June 2018 B...
# 198  Education Details \r\nJune 2014 to June 2018 B...
# 213  Education Details \r\nJune 2014 to June 2018 B...
# 216  SKILLS: â¢ Knowledge of software / computer: ...
# 186  SKILLS: â¢ Knowledge of software / computer: ...
#
#
# Top 10 resumes for category: Sales
#     Category Category Area                                             Resume
# 263    Sales      Non-tech  IT Skills: MS Office. Photoshop. SQL Server.Ed...
# 238    Sales      Non-tech  IT Skills: MS Office. Photoshop. SQL Server.Ed...
# 258    Sales      Non-tech  IT Skills: MS Office. Photoshop. SQL Server.Ed...
# 253    Sales      Non-tech  IT Skills: MS Office. Photoshop. SQL Server.Ed...
# 233    Sales      Non-tech  IT Skills: MS Office. Photoshop. SQL Server.Ed...
# 248    Sales      Non-tech  IT Skills: MS Office. Photoshop. SQL Server.Ed...
# 228    Sales      Non-tech  IT Skills: MS Office. Photoshop. SQL Server.Ed...
# 243    Sales      Non-tech  IT Skills: MS Office. Photoshop. SQL Server.Ed...
# 261    Sales      Non-tech  SKILLS 1. MS-Office 2. Good Communication skil...
# 256    Sales      Non-tech  SKILLS 1. MS-Office 2. Good Communication skil...
#
#
# Top 10 resumes for category: Health and fitness
#                Category Category Area  \
# 293  Health and fitness      Non-tech
# 287  Health and fitness      Non-tech
# 269  Health and fitness      Non-tech
# 275  Health and fitness      Non-tech
# 281  Health and fitness      Non-tech
# 270  Health and fitness      Non-tech
# 294  Health and fitness      Non-tech
# 276  Health and fitness      Non-tech
# 267  Health and fitness      Non-tech
# 291  Health and fitness      Non-tech
#
#                                                 Resume
# 293  Education Details \r\nJanuary 2009 P.G. Sports...
# 287  Education Details \r\nJanuary 2009 P.G. Sports...
# 269  Education Details \r\nJanuary 2009 P.G. Sports...
# 275  Education Details \r\nJanuary 2009 P.G. Sports...
# 281  Education Details \r\nJanuary 2009 P.G. Sports...
# 270  Education Details \r\nMay 2014 Diploma Nutriti...
# 294  Education Details \r\nMay 2014 Diploma Nutriti...
# 276  Education Details \r\nMay 2014 Diploma Nutriti...
# 267  Personal Skills: â¢ Good verbal and written c...
# 291  Personal Skills: â¢ Good verbal and written c...
#
#
# Top 10 resumes for category: Civil Engineer
#            Category Category Area  \
# 299  Civil Engineer      Non-tech
# 317  Civil Engineer      Non-tech
# 305  Civil Engineer      Non-tech
# 316  Civil Engineer      Non-tech
# 310  Civil Engineer      Non-tech
# 304  Civil Engineer      Non-tech
# 298  Civil Engineer      Non-tech
# 301  Civil Engineer      Non-tech
# 307  Civil Engineer      Non-tech
# 315  Civil Engineer      Non-tech
#
#                                                 Resume
# 299  COMPUTER KNOWLEDGE â¢ Drafting tools: AutoCAD...
# 317  COMPUTER KNOWLEDGE â¢ Drafting tools: AutoCAD...
# 305  COMPUTER KNOWLEDGE â¢ Drafting tools: AutoCAD...
# 316  Computer Skills â¢ Holder of valid KSA licens...
# 310  Computer Skills â¢ Holder of valid KSA licens...
# 304  Computer Skills â¢ Holder of valid KSA licens...
# 298  Computer Skills â¢ Holder of valid KSA licens...
# 301  Education Details \r\n B.E in Civil Engineerin...
# 307  Education Details \r\n B.E in Civil Engineerin...
# 315  SKILLS â¢ 1.Autocad â¢ 2.Pro v â¢ 3.Catia â...
#
#
# Top 10 resumes for category: Java Developer
#            Category Category Area  \
# 369  Java Developer          Tech
# 355  Java Developer          Tech
# 397  Java Developer          Tech
# 327  Java Developer          Tech
# 383  Java Developer          Tech
# 395  Java Developer          Tech
# 396  Java Developer          Tech
# 382  Java Developer          Tech
# 325  Java Developer          Tech
# 381  Java Developer          Tech
#
#                                                 Resume
# 369  Operating Systems Windows XP, 7, 10. Tools/Pac...
# 355  Operating Systems Windows XP, 7, 10. Tools/Pac...
# 397  Operating Systems Windows XP, 7, 10. Tools/Pac...
# 327  Operating Systems Windows XP, 7, 10. Tools/Pac...
# 383  Operating Systems Windows XP, 7, 10. Tools/Pac...
# 395  TECHNICALSKILLS SpringMVC, Hibernate, JDBC, Ja...
# 396  TECHNICALSKILLS SpringMVC, Hibernate, JDBC, Ja...
# 382  TECHNICALSKILLS SpringMVC, Hibernate, JDBC, Ja...
# 325  TECHNICALSKILLS SpringMVC, Hibernate, JDBC, Ja...
# 381  TECHNICALSKILLS SpringMVC, Hibernate, JDBC, Ja...
#
#
# Top 10 resumes for category: Business Analyst
#              Category Category Area  \
# 418  Business Analyst      Non-tech
# 404  Business Analyst      Non-tech
# 410  Business Analyst      Non-tech
# 420  Business Analyst      Non-tech
# 406  Business Analyst      Non-tech
# 414  Business Analyst      Non-tech
# 409  Business Analyst      Non-tech
# 423  Business Analyst      Non-tech
# 413  Business Analyst      Non-tech
# 427  Business Analyst      Non-tech
#
#                                                 Resume
# 418  Technical Skills Application Servers: IIS 6.0,...
# 404  Technical Skills Application Servers: IIS 6.0,...
# 410  IT Skills: Area Exposure Modeling Tool: Bizagi...
# 420  IT Skills: Area Exposure Modeling Tool: Bizagi...
# 406  IT Skills: Area Exposure Modeling Tool: Bizagi...
# 414  IT Skills: Area Exposure Modeling Tool: Bizagi...
# 409  Key Skills - Requirement Gathering - Requireme...
# 423  Key Skills - Requirement Gathering - Requireme...
# 413  Key Skills - Requirement Gathering - Requireme...
# 427  Key Skills - Requirement Gathering - Requireme...
#
#
# Top 10 resumes for category: SAP Developer
#           Category Category Area  \
# 444  SAP Developer          Tech
# 438  SAP Developer          Tech
# 432  SAP Developer          Tech
# 450  SAP Developer          Tech
# 437  SAP Developer          Tech
# 443  SAP Developer          Tech
# 445  SAP Developer          Tech
# 451  SAP Developer          Tech
# 433  SAP Developer          Tech
# 436  SAP Developer          Tech
#
#                                                 Resume
# 444  Competencies: SAP Business Intelligence Versio...
# 438  Competencies: SAP Business Intelligence Versio...
# 432  Competencies: SAP Business Intelligence Versio...
# 450  Competencies: SAP Business Intelligence Versio...
# 437  Skills: â¢ ETL â¢ Data Warehousing â¢ SQL/P...
# 443  Skills: â¢ ETL â¢ Data Warehousing â¢ SQL/P...
# 445  Education Details \r\nJuly 2008 to February 20...
# 451  Education Details \r\nJuly 2008 to February 20...
# 433  Education Details \r\nJuly 2008 to February 20...
# 436  Education Details \r\n\r\nSAP Technical Archit...
#
#
# Top 10 resumes for category: Automation Testing
#                Category Category Area  \
# 465  Automation Testing          Tech
# 478  Automation Testing          Tech
# 480  Automation Testing          Tech
# 467  Automation Testing          Tech
# 472  Automation Testing          Tech
# 476  Automation Testing          Tech
# 459  Automation Testing          Tech
# 462  Automation Testing          Tech
# 475  Automation Testing          Tech
# 477  Automation Testing          Tech
#
#                                                 Resume
# 465  Technical Skills Summary I have completed "COR...
# 478  Technical Skills Summary I have completed "COR...
# 480  Technical Skills Summary I have completed "COR...
# 467  Technical Skills Summary I have completed "COR...
# 472  Technical Skills Summary I have completed "COR...
# 476  Technical Skills Summary I have completed "COR...
# 459  Technical Skills Summary I have completed "COR...
# 462  SKILLS Agile Methodology Scrum, Kanban, Extrem...
# 475  SKILLS Agile Methodology Scrum, Kanban, Extrem...
# 477  SKILLS Agile Methodology Scrum, Kanban, Extrem...
#
#
# Top 10 resumes for category: Electrical Engineering
#                    Category Category Area  \
# 495  Electrical Engineering      Non-tech
# 510  Electrical Engineering      Non-tech
# 505  Electrical Engineering      Non-tech
# 485  Electrical Engineering      Non-tech
# 500  Electrical Engineering      Non-tech
# 483  Electrical Engineering      Non-tech
# 488  Electrical Engineering      Non-tech
# 493  Electrical Engineering      Non-tech
# 503  Electrical Engineering      Non-tech
# 491  Electrical Engineering      Non-tech
#
#                                                 Resume
# 495  Education Details \r\nJanuary 2012 to January ...
# 510  Education Details \r\nJanuary 2012 to January ...
# 505  Education Details \r\nJanuary 2012 to January ...
# 485  Education Details \r\nJanuary 2012 to January ...
# 500  Education Details \r\nJanuary 2012 to January ...
# 483  â¢ Achievement oriented with people managemen...
# 488  â¢ Achievement oriented with people managemen...
# 493  â¢ Achievement oriented with people managemen...
# 503  â¢ Achievement oriented with people managemen...
# 491  Skills: 1) MC Office 2) AutoCAD 2016 3) Introd...
#
#
# Top 10 resumes for category: Operations Manager
#                Category Category Area  \
# 540  Operations Manager      Non-tech
# 536  Operations Manager      Non-tech
# 520  Operations Manager      Non-tech
# 524  Operations Manager      Non-tech
# 528  Operations Manager      Non-tech
# 544  Operations Manager      Non-tech
# 516  Operations Manager      Non-tech
# 512  Operations Manager      Non-tech
# 532  Operations Manager      Non-tech
# 541  Operations Manager      Non-tech
#
#                                                 Resume
# 540  KEY COMPETENCIES â¶Multi - Operations Managem...
# 536  KEY COMPETENCIES â¶Multi - Operations Managem...
# 520  KEY COMPETENCIES â¶Multi - Operations Managem...
# 524  KEY COMPETENCIES â¶Multi - Operations Managem...
# 528  KEY COMPETENCIES â¶Multi - Operations Managem...
# 544  KEY COMPETENCIES â¶Multi - Operations Managem...
# 516  KEY COMPETENCIES â¶Multi - Operations Managem...
# 512  KEY COMPETENCIES â¶Multi - Operations Managem...
# 532  KEY COMPETENCIES â¶Multi - Operations Managem...
# 541  IT SKILLS â¢ Well versed with MS Office and I...
#
#
# Top 10 resumes for category: Python Developer
#              Category Category Area  \
# 556  Python Developer          Tech
# 562  Python Developer          Tech
# 592  Python Developer          Tech
# 568  Python Developer          Tech
# 586  Python Developer          Tech
# 574  Python Developer          Tech
# 580  Python Developer          Tech
# 598  Python Developer          Tech
# 596  Python Developer          Tech
# 554  Python Developer          Tech
#
#                                                 Resume
# 556  â¢ Operating Systems: Windows â¢ Others: MS ...
# 562  â¢ Operating Systems: Windows â¢ Others: MS ...
# 592  â¢ Operating Systems: Windows â¢ Others: MS ...
# 568  â¢ Operating Systems: Windows â¢ Others: MS ...
# 586  â¢ Operating Systems: Windows â¢ Others: MS ...
# 574  â¢ Operating Systems: Windows â¢ Others: MS ...
# 580  â¢ Operating Systems: Windows â¢ Others: MS ...
# 598  â¢ Operating Systems: Windows â¢ Others: MS ...
# 596  Technical Skills: Languages Python Python Fram...
# 554  Technical Skills: Languages Python Python Fram...
#
#
# Top 10 resumes for category: DevOps Engineer
#             Category Category Area  \
# 636  DevOps Engineer          Tech
# 624  DevOps Engineer          Tech
# 606  DevOps Engineer          Tech
# 633  DevOps Engineer          Tech
# 599  DevOps Engineer          Tech
# 621  DevOps Engineer          Tech
# 609  DevOps Engineer          Tech
# 615  DevOps Engineer          Tech
# 645  DevOps Engineer          Tech
# 639  DevOps Engineer          Tech
#
#                                                 Resume
# 636  Skills VISA B1-VISA (USA) Onsite Visits to Swe...
# 624  Skills VISA B1-VISA (USA) Onsite Visits to Swe...
# 606  Skills VISA B1-VISA (USA) Onsite Visits to Swe...
# 633  Skills VISA B1-VISA (USA) Onsite Visits to Swe...
# 599  Skills VISA B1-VISA (USA) Onsite Visits to Swe...
# 621  Skills VISA B1-VISA (USA) Onsite Visits to Swe...
# 609  Skills VISA B1-VISA (USA) Onsite Visits to Swe...
# 615  Skills VISA B1-VISA (USA) Onsite Visits to Swe...
# 645  Skills VISA B1-VISA (USA) Onsite Visits to Swe...
# 639  Skills VISA B1-VISA (USA) Onsite Visits to Swe...
#
#
# Top 10 resumes for category: Network Security Engineer
#                       Category Category Area  \
# 658  Network Security Engineer          Tech
# 673  Network Security Engineer          Tech
# 678  Network Security Engineer          Tech
# 663  Network Security Engineer          Tech
# 668  Network Security Engineer          Tech
# 674  Network Security Engineer          Tech
# 669  Network Security Engineer          Tech
# 659  Network Security Engineer          Tech
# 664  Network Security Engineer          Tech
# 672  Network Security Engineer          Tech
#
#                                                 Resume
# 658  Operating Systems: Windows, Linux, Ubuntu Netw...
# 673  Operating Systems: Windows, Linux, Ubuntu Netw...
# 678  Operating Systems: Windows, Linux, Ubuntu Netw...
# 663  Operating Systems: Windows, Linux, Ubuntu Netw...
# 668  Operating Systems: Windows, Linux, Ubuntu Netw...
# 674  Skill Set â¢ Experience in Implementing, and ...
# 669  Skill Set â¢ Experience in Implementing, and ...
# 659  Skill Set â¢ Experience in Implementing, and ...
# 664  Skill Set â¢ Experience in Implementing, and ...
# 672  Technical Expertise: â¢ Cisco ASA, Checkpoint...
#
#
# Top 10 resumes for category: PMO
#     Category Category Area                                             Resume
# 707      PMO      Non-tech  AREA OF EXPERTISE (PROFILE) Around 10 plus yea...
# 680      PMO      Non-tech  AREA OF EXPERTISE (PROFILE) Around 10 plus yea...
# 689      PMO      Non-tech  AREA OF EXPERTISE (PROFILE) Around 10 plus yea...
# 686      PMO      Non-tech  AREA OF EXPERTISE (PROFILE) Around 10 plus yea...
# 683      PMO      Non-tech  AREA OF EXPERTISE (PROFILE) Around 10 plus yea...
# 695      PMO      Non-tech  AREA OF EXPERTISE (PROFILE) Around 10 plus yea...
# 692      PMO      Non-tech  AREA OF EXPERTISE (PROFILE) Around 10 plus yea...
# 701      PMO      Non-tech  AREA OF EXPERTISE (PROFILE) Around 10 plus yea...
# 704      PMO      Non-tech  AREA OF EXPERTISE (PROFILE) Around 10 plus yea...
# 698      PMO      Non-tech  AREA OF EXPERTISE (PROFILE) Around 10 plus yea...
#
#
# Top 10 resumes for category: Database
#      Category Category Area                                             Resume
# 736  Database          Tech  TECHNICAL SKILL: Operating System LINUX, Windo...
# 725  Database          Tech  TECHNICAL SKILL: Operating System LINUX, Windo...
# 714  Database          Tech  TECHNICAL SKILL: Operating System LINUX, Windo...
# 737  Database          Tech  Technical Skills Databases: Oracle RDBMS- 10g,...
# 715  Database          Tech  Technical Skills Databases: Oracle RDBMS- 10g,...
# 709  Database          Tech  TECHNICAL EXPERTISE â¢ DB Languages: SQL â¢ ...
# 720  Database          Tech  TECHNICAL EXPERTISE â¢ DB Languages: SQL â¢ ...
# 731  Database          Tech  TECHNICAL EXPERTISE â¢ DB Languages: SQL â¢ ...
# 716  Database          Tech  Software Skills: * RDBMS: MS SQL SERVER 2000/2...
# 727  Database          Tech  Software Skills: * RDBMS: MS SQL SERVER 2000/2...
#
#
# Top 10 resumes for category: Hadoop
#     Category Category Area                                             Resume
# 773   Hadoop          Tech  Areas of expertise â¢ Big Data Ecosystems: Ha...
# 752   Hadoop          Tech  Areas of expertise â¢ Big Data Ecosystems: Ha...
# 759   Hadoop          Tech  Areas of expertise â¢ Big Data Ecosystems: Ha...
# 766   Hadoop          Tech  Areas of expertise â¢ Big Data Ecosystems: Ha...
# 745   Hadoop          Tech  Areas of expertise â¢ Big Data Ecosystems: Ha...
# 780   Hadoop          Tech  Areas of expertise â¢ Big Data Ecosystems: Ha...
# 758   Hadoop          Tech  â¢ Operating systems:-Linux- Ubuntu, Windows ...
# 751   Hadoop          Tech  â¢ Operating systems:-Linux- Ubuntu, Windows ...
# 765   Hadoop          Tech  â¢ Operating systems:-Linux- Ubuntu, Windows ...
# 779   Hadoop          Tech  â¢ Operating systems:-Linux- Ubuntu, Windows ...
#
#
# Top 10 resumes for category: ETL Developer
#           Category Category Area  \
# 814  ETL Developer          Tech
# 809  ETL Developer          Tech
# 804  ETL Developer          Tech
# 784  ETL Developer          Tech
# 794  ETL Developer          Tech
# 789  ETL Developer          Tech
# 819  ETL Developer          Tech
# 797  ETL Developer          Tech
# 792  ETL Developer          Tech
# 817  ETL Developer          Tech
#
#                                                 Resume
# 814  Technical Summary â¢ Knowledge of Informatica...
# 809  Technical Summary â¢ Knowledge of Informatica...
# 804  Technical Summary â¢ Knowledge of Informatica...
# 784  Technical Summary â¢ Knowledge of Informatica...
# 794  Technical Summary â¢ Knowledge of Informatica...
# 789  Technical Summary â¢ Knowledge of Informatica...
# 819  Technical Summary â¢ Knowledge of Informatica...
# 797  SKILL SET â Talend Big Data â Informatica ...
# 792  SKILL SET â Talend Big Data â Informatica ...
# 817  SKILL SET â Talend Big Data â Informatica ...
#
#
# Top 10 resumes for category: DotNet Developer
#              Category Category Area  \
# 838  DotNet Developer          Tech
# 831  DotNet Developer          Tech
# 830  DotNet Developer          Tech
# 844  DotNet Developer          Tech
# 851  DotNet Developer          Tech
# 837  DotNet Developer          Tech
# 835  DotNet Developer          Tech
# 842  DotNet Developer          Tech
# 828  DotNet Developer          Tech
# 829  DotNet Developer          Tech
#
#                                                 Resume
# 838  TECHNICAL SKILLS â¢ Web Technologies: ASP .NE...
# 831  TECHNICAL SKILLS â¢ Web Technologies: ASP .NE...
# 830  TECHNICAL SKILLS â Programming Languages: C#...
# 844  TECHNICAL SKILLS â Programming Languages: C#...
# 851  TECHNICAL SKILLS â Programming Languages: C#...
# 837  TECHNICAL SKILLS â Programming Languages: C#...
# 835  Technologies ASP.NET, MVC 3.0/4.0/5.0, Unit Te...
# 842  Technologies ASP.NET, MVC 3.0/4.0/5.0, Unit Te...
# 828  Technologies ASP.NET, MVC 3.0/4.0/5.0, Unit Te...
# 829  Technical Skills CATEGORY SKILLS Language C, C...
#
#
# Top 10 resumes for category: Blockchain
#        Category Category Area  \
# 858  Blockchain          Tech
# 873  Blockchain          Tech
# 863  Blockchain          Tech
# 883  Blockchain          Tech
# 888  Blockchain          Tech
# 853  Blockchain          Tech
# 890  Blockchain          Tech
# 855  Blockchain          Tech
# 885  Blockchain          Tech
# 860  Blockchain          Tech
#
#                                                 Resume
# 858  Skills Strong CS fundamentals and problem solv...
# 873  Skills Strong CS fundamentals and problem solv...
# 863  Skills Strong CS fundamentals and problem solv...
# 883  Skills Strong CS fundamentals and problem solv...
# 888  Skills Strong CS fundamentals and problem solv...
# 853  Skills Strong CS fundamentals and problem solv...
# 890  SOFTWARE SKILLS: Languages: C, C++ & java Oper...
# 855  SOFTWARE SKILLS: Languages: C, C++ & java Oper...
# 885  SOFTWARE SKILLS: Languages: C, C++ & java Oper...
# 860  SOFTWARE SKILLS: Languages: C, C++ & java Oper...
#
#
# Top 10 resumes for category: Testing
#     Category Category Area                                             Resume
# 928  Testing          Tech  COMPUTER PROFICIENCY â¢ Basic: MS-Office (Pow...
# 893  Testing          Tech  COMPUTER PROFICIENCY â¢ Basic: MS-Office (Pow...
# 956  Testing          Tech  COMPUTER PROFICIENCY â¢ Basic: MS-Office (Pow...
# 900  Testing          Tech  COMPUTER PROFICIENCY â¢ Basic: MS-Office (Pow...
# 942  Testing          Tech  COMPUTER PROFICIENCY â¢ Basic: MS-Office (Pow...
# 935  Testing          Tech  COMPUTER PROFICIENCY â¢ Basic: MS-Office (Pow...
# 921  Testing          Tech  COMPUTER PROFICIENCY â¢ Basic: MS-Office (Pow...
# 949  Testing          Tech  COMPUTER PROFICIENCY â¢ Basic: MS-Office (Pow...
# 907  Testing          Tech  COMPUTER PROFICIENCY â¢ Basic: MS-Office (Pow...
# 931  Testing          Tech  PERSONAL SKILLS â¢ Quick learner, â¢ Eagerne...

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC

# Initialize SVM classifier
svm_clf = SVC(kernel='linear')


encoded_resumes_all = tokenizer.batch_encode_plus(data["Resume"].tolist(),
                                                  max_length=512,
                                                  truncation=True,
                                                  padding='max_length',
                                                  return_tensors='pt')

resume_dataset_all = ResumeDataset(encoded_resumes_all)
resume_loader_all = DataLoader(resume_dataset_all, batch_size=8, shuffle=False)

# Calculate embeddings for all resumes
resume_embeddings = []
for batch in tqdm(resume_loader_all, desc=f'Embeddings for all resumes', leave=False):
    input_ids = batch['input_ids'].to(device)
    attention_mask = batch['attention_mask'].to(device)
    with torch.no_grad():
        outputs = model(input_ids, attention_mask)
    resume_embeddings.append(outputs.cpu().numpy())
resume_embeddings = np.concatenate(resume_embeddings)


accuracy_per_category = []
precision_per_category = []
recall_per_category = []
cross_val_scores_per_category = []


for category, top_10_resumes in top_10_resumes_per_category.items():

    category_indices = data[data['Category'] == category].index

    # Create true labels (1 for resumes in the current category, 0 otherwise)
    y_true_category = [1 if idx in category_indices else 0 for idx in range(len(data))]

    # Create predicted labels (1 for top 10 resumes, 0 otherwise)
    y_pred_category = [1 if idx in top_10_resumes.index else 0 for idx in range(len(data))]

    accuracy_category = accuracy_score(y_true_category, y_pred_category)
    accuracy_per_category.append(accuracy_category)

    precision_category = precision_score(y_true_category, y_pred_category)
    precision_per_category.append(precision_category)

    recall_category = recall_score(y_true_category, y_pred_category)
    recall_per_category.append(recall_category)

    # Perform cross-validation for the current category
    cross_val_scores_category = cross_val_score(svm_clf, resume_embeddings, y_pred_category, cv=5)
    cross_val_scores_per_category.append(cross_val_scores_category)

for i, category in enumerate(top_10_resumes_per_category.keys()):
    print("Category:", category)
    print("Accuracy:", accuracy_per_category[i])
    print("Precision:", precision_per_category[i])
    print("Recall:", recall_per_category[i])
    print("Cross-Validation Scores:", cross_val_scores_per_category[i])
    print()
# Out:
# Embeddings for all resumes:   0%|          | 0/121 [00:00<?, ?it/s]<ipython-input-5-9e5907f05fcd>:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# Category: Data Science
# Accuracy: 0.9688149688149689
# Precision: 1.0
# Recall: 0.25
# Cross-Validation Scores: [0.94818653 1.         1.         1.         1.        ]
#
# Category: HR
# Accuracy: 0.9646569646569647
# Precision: 1.0
# Recall: 0.22727272727272727
# Cross-Validation Scores: [0.90673575 1.         0.96354167 1.         1.        ]
#
# Category: Advocate
# Accuracy: 0.9896049896049897
# Precision: 1.0
# Recall: 0.5
# Cross-Validation Scores: [0.96891192 0.99481865 0.99479167 1.         1.        ]
#
# Category: Arts
# Accuracy: 0.972972972972973
# Precision: 1.0
# Recall: 0.2777777777777778
# Cross-Validation Scores: [0.97927461 1.         1.         1.         1.        ]
#
# Category: Web Designing
# Accuracy: 0.9636174636174636
# Precision: 1.0
# Recall: 0.2222222222222222
# Cross-Validation Scores: [0.95854922 0.98963731 0.98958333 0.98958333 0.98958333]
#
# Category: Mechanical Engineer
# Accuracy: 0.9688149688149689
# Precision: 1.0
# Recall: 0.25
# Cross-Validation Scores: [0.99481865 0.97409326 1.         0.99479167 1.        ]
#
# Category: Sales
# Accuracy: 0.9688149688149689
# Precision: 1.0
# Recall: 0.25
# Cross-Validation Scores: [1.         0.96891192 1.         0.99479167 0.99479167]
#
# Category: Health and fitness
# Accuracy: 0.9792099792099792
# Precision: 1.0
# Recall: 0.3333333333333333
# Cross-Validation Scores: [0.99481865 0.88082902 0.99479167 0.99479167 0.99479167]
#
# Category: Civil Engineer
# Accuracy: 0.9854469854469855
# Precision: 1.0
# Recall: 0.4166666666666667
# Cross-Validation Scores: [1.         0.96891192 0.99479167 0.99479167 1.        ]
#
# Category: Java Developer
# Accuracy: 0.9230769230769231
# Precision: 1.0
# Recall: 0.11904761904761904
# Cross-Validation Scores: [0.99481865 0.95854922 0.98958333 0.99479167 0.99479167]
#
# Category: Business Analyst
# Accuracy: 0.9812889812889813
# Precision: 1.0
# Recall: 0.35714285714285715
# Cross-Validation Scores: [1.         0.99481865 0.96875    1.         0.98958333]
#
# Category: SAP Developer
# Accuracy: 0.9854469854469855
# Precision: 1.0
# Recall: 0.4166666666666667
# Cross-Validation Scores: [1.         0.98963731 0.96875    1.         1.        ]
#
# Category: Automation Testing
# Accuracy: 0.9833679833679834
# Precision: 1.0
# Recall: 0.38461538461538464
# Cross-Validation Scores: [0.99481865 1.         0.96875    0.99479167 1.        ]
#
# Category: Electrical Engineering
# Accuracy: 0.9792099792099792
# Precision: 1.0
# Recall: 0.3333333333333333
# Cross-Validation Scores: [1.         0.99481865 0.94791667 1.         1.        ]
#
# Category: Operations Manager
# Accuracy: 0.9688149688149689
# Precision: 1.0
# Recall: 0.25
# Cross-Validation Scores: [1.         1.         0.94791667 1.         0.99479167]
#
# Category: Python Developer
# Accuracy: 0.9604989604989606
# Precision: 1.0
# Recall: 0.20833333333333334
# Cross-Validation Scores: [0.99481865 1.         1.         1.         0.99479167]
#
# Category: DevOps Engineer
# Accuracy: 0.9532224532224532
# Precision: 1.0
# Recall: 0.18181818181818182
# Cross-Validation Scores: [1.         1.         1.         0.96354167 1.        ]
#
# Category: Network Security Engineer
# Accuracy: 0.9844074844074844
# Precision: 1.0
# Recall: 0.4
# Cross-Validation Scores: [1.         1.         1.         0.94791667 1.        ]
#
# Category: PMO
# Accuracy: 0.9792099792099792
# Precision: 1.0
# Recall: 0.3333333333333333
# Cross-Validation Scores: [1. 1. 1. 1. 1.]
#
# Category: Database
# Accuracy: 0.9760914760914761
# Precision: 1.0
# Recall: 0.30303030303030304
# Cross-Validation Scores: [1.         0.98963731 1.         0.90104167 0.99479167]
#
# Category: Hadoop
# Accuracy: 0.9667359667359667
# Precision: 1.0
# Recall: 0.23809523809523808
# Cross-Validation Scores: [0.99481865 0.99481865 0.99479167 0.99479167 0.99479167]
#
# Category: ETL Developer
# Accuracy: 0.9688149688149689
# Precision: 1.0
# Recall: 0.25
# Cross-Validation Scores: [1.         0.99481865 0.99479167 1.         0.96875   ]
#
# Category: DotNet Developer
# Accuracy: 0.9812889812889813
# Precision: 1.0
# Recall: 0.35714285714285715
# Cross-Validation Scores: [0.99481865 0.99481865 1.         0.97916667 0.96875   ]
#
# Category: Blockchain
# Accuracy: 0.9688149688149689
# Precision: 1.0
# Recall: 0.25
# Cross-Validation Scores: [0.99481865 0.99481865 1.         0.99479167 0.96875   ]
#
# Category: Testing
# Accuracy: 0.9376299376299376
# Precision: 1.0
# Recall: 0.14285714285714285
# Cross-Validation Scores: [1.         1.         0.99479167 1.         0.94791667]
